# %% [markdown]
# <a href="https://colab.research.google.com/github/MI177/IntersemestralesPython/blob/main/Preprocesamiento2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from datetime import datetime
df = pd.DataFrame({'nombres':('Juan Pérez',
                                 'María Sánchez'
                                 , 'Jorge Vargas',
                                 'Rodrigo Martínez'),
            'fechas':(datetime(1995,12,21),
                      datetime(1989,1,13),
                      datetime(1992,9,14),
                      datetime(1993,7,8)),
            'saldo': (2500,
                      5345,
                      np.NaN,
                      11323.2),
            'al_corriente':(True,
                            True,
                            False,
                            True)})

df
# Out:
#             nombres     fechas    saldo  al_corriente
# 0        Juan Pérez 1995-12-21   2500.0          True
# 1     María Sánchez 1989-01-13   5345.0          True
# 2      Jorge Vargas 1992-09-14      NaN         False
# 3  Rodrigo Martínez 1993-07-08  11323.2          True

# %%
#Operador .iloc recupera a partir de la posocion de los elementos
#data.iloc[<filas>,<columnas>]

#primer fila
print(type(df.iloc[0]))
df.iloc[0]
# Out:
# <class 'pandas.core.series.Series'>
# nombres                  Juan Pérez
# fechas          1995-12-21 00:00:00
# saldo                        2500.0
# al_corriente                   True
# Name: 0, dtype: object

# %%
#segunda fila
df.iloc[0]
# Out:
# nombres                  Juan Pérez
# fechas          1995-12-21 00:00:00
# saldo                        2500.0
# al_corriente                   True
# Name: 0, dtype: object

# %%
#ultima fila
df.iloc[-1]
# Out:
# nombres            Rodrigo Martínez
# fechas          1993-07-08 00:00:00
# saldo                       11323.2
# al_corriente                   True
# Name: 3, dtype: object

# %%
df.iloc[:,0]
# Out:
# 0          Juan Pérez
# 1       María Sánchez
# 2        Jorge Vargas
# 3    Rodrigo Martínez
# Name: nombres, dtype: object

# %%
#segunda columna
df.iloc[:,0]
# Out:
# 0          Juan Pérez
# 1       María Sánchez
# 2        Jorge Vargas
# 3    Rodrigo Martínez
# Name: nombres, dtype: object

# %%
#ultima columna
df.iloc[:,-1]
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# Name: al_corriente, dtype: bool

# %%
#rango de filas
df.iloc[1:3]
# Out:
#          nombres     fechas   saldo  al_corriente
# 1  María Sánchez 1989-01-13  5345.0          True
# 2   Jorge Vargas 1992-09-14     NaN         False

# %%
df.iloc[0:3:2]
# Out:
#         nombres     fechas   saldo  al_corriente
# 0    Juan Pérez 1995-12-21  2500.0          True
# 2  Jorge Vargas 1992-09-14     NaN         False

# %%
df.iloc[:,1:3]
# Out:
#       fechas    saldo
# 0 1995-12-21   2500.0
# 1 1989-01-13   5345.0
# 2 1992-09-14      NaN
# 3 1993-07-08  11323.2

# %%
#lista de filas
df.iloc[[1,3,0]]
# Out:
#             nombres     fechas    saldo  al_corriente
# 1     María Sánchez 1989-01-13   5345.0          True
# 3  Rodrigo Martínez 1993-07-08  11323.2          True
# 0        Juan Pérez 1995-12-21   2500.0          True

# %%
#lista de columnas
df.iloc[:,[1,3,0]]
# Out:
#       fechas  al_corriente           nombres
# 0 1995-12-21          True        Juan Pérez
# 1 1989-01-13          True     María Sánchez
# 2 1992-09-14         False      Jorge Vargas
# 3 1993-07-08          True  Rodrigo Martínez

# %%
#combinacion lista de filas y columnas
df.iloc[[1,3,0],[1,3,0]]
# Out:
#       fechas  al_corriente           nombres
# 1 1989-01-13          True     María Sánchez
# 3 1993-07-08          True  Rodrigo Martínez
# 0 1995-12-21          True        Juan Pérez

# %%
df.iloc[1,[1,3,0]]
# Out:
# fechas          1989-01-13 00:00:00
# al_corriente                   True
# nombres               María Sánchez
# Name: 1, dtype: object

# %%
#todas las columnas de la primer fila
df.iloc[1,:]
#df.iloc[1,'fechas'] X
# Out:
# nombres               María Sánchez
# fechas          1989-01-13 00:00:00
# saldo                        5345.0
# al_corriente                   True
# Name: 1, dtype: object

# %%
#loc localiza por etiqueta de datos | toma la etiqueta 1 2 y 3, nombre de renglones
df.loc[1:3]
# Out:
#             nombres     fechas    saldo  al_corriente
# 1     María Sánchez 1989-01-13   5345.0          True
# 2      Jorge Vargas 1992-09-14      NaN         False
# 3  Rodrigo Martínez 1993-07-08  11323.2          True

# %%
#una columna
df.loc[:,'saldo']
# Out:
# 0     2500.0
# 1     5345.0
# 2        NaN
# 3    11323.2
# Name: saldo, dtype: float64

# %%
#rango de columnas
df.loc[:,'saldo':'al_corriente']
# Out:
#      saldo  al_corriente
# 0   2500.0          True
# 1   5345.0          True
# 2      NaN         False
# 3  11323.2          True

# %%
#el orde si importa
df.loc[:,'saldo':'fechas']
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
df.loc[:,'fechas':'saldo']
# Out:
#       fechas    saldo
# 0 1995-12-21   2500.0
# 1 1989-01-13   5345.0
# 2 1992-09-14      NaN
# 3 1993-07-08  11323.2

# %%
df.loc[:,['fechas','saldo','nombres']]
# Out:
#       fechas    saldo           nombres
# 0 1995-12-21   2500.0        Juan Pérez
# 1 1989-01-13   5345.0     María Sánchez
# 2 1992-09-14      NaN      Jorge Vargas
# 3 1993-07-08  11323.2  Rodrigo Martínez

# %% [markdown]
# columnas con loc
# renglones con iloc

# %%
df.loc[1,['fechas','saldo','nombres']]
# Out:
# fechas     1989-01-13 00:00:00
# saldo                   5345.0
# nombres          María Sánchez
# Name: 1, dtype: object

# %%
df.loc[1:3,['fechas','saldo','nombres']]
# Out:
#       fechas    saldo           nombres
# 1 1989-01-13   5345.0     María Sánchez
# 2 1992-09-14      NaN      Jorge Vargas
# 3 1993-07-08  11323.2  Rodrigo Martínez

# %%
#lista de renglones y lista de columnas
df.loc[[1,3,2],['fechas','saldo','nombres']]
# Out:
#       fechas    saldo           nombres
# 1 1989-01-13   5345.0     María Sánchez
# 3 1993-07-08  11323.2  Rodrigo Martínez
# 2 1992-09-14      NaN      Jorge Vargas

# %%
print(df.loc[1:3])
print("---------".center(60,'*'))
print(df.iloc[1:3])
# Out:
#             nombres     fechas    saldo  al_corriente
# 1     María Sánchez 1989-01-13   5345.0          True
# 2      Jorge Vargas 1992-09-14      NaN         False
# 3  Rodrigo Martínez 1993-07-08  11323.2          True
# *************************---------**************************
#          nombres     fechas   saldo  al_corriente
# 1  María Sánchez 1989-01-13  5345.0          True
# 2   Jorge Vargas 1992-09-14     NaN         False

# %%
df_iloc=df.iloc[1:3]
df_iloc
# Out:
#          nombres     fechas   saldo  al_corriente
# 1  María Sánchez 1989-01-13  5345.0          True
# 2   Jorge Vargas 1992-09-14     NaN         False

# %%
print(df_iloc.loc[1])
print("---------".center(60,'*'))
print(df_iloc.iloc[1])
# Out:
# nombres               María Sánchez
# fechas          1989-01-13 00:00:00
# saldo                        5345.0
# al_corriente                   True
# Name: 1, dtype: object
# *************************---------**************************
# nombres                Jorge Vargas
# fechas          1992-09-14 00:00:00
# saldo                           NaN
# al_corriente                  False
# Name: 2, dtype: object

# %%
df
# Out:
#             nombres     fechas    saldo  al_corriente
# 0        Juan Pérez 1995-12-21   2500.0          True
# 1     María Sánchez 1989-01-13   5345.0          True
# 2      Jorge Vargas 1992-09-14      NaN         False
# 3  Rodrigo Martínez 1993-07-08  11323.2          True

# %%
#recuperando de serie booleana
df['saldo']>3000
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# Name: saldo, dtype: bool

# %%
df.loc[df['saldo']>3000]
# Out:
#             nombres     fechas    saldo  al_corriente
# 1     María Sánchez 1989-01-13   5345.0          True
# 3  Rodrigo Martínez 1993-07-08  11323.2          True

# %%
df.loc[df['saldo']>3000,['nombres','saldo']]
# Out:
#             nombres    saldo
# 1     María Sánchez   5345.0
# 3  Rodrigo Martínez  11323.2

# %%
ss3=df['saldo']>3000
print(type(ss3))
ss3
# Out:
# <class 'pandas.core.series.Series'>
# 0    False
# 1     True
# 2    False
# 3     True
# Name: saldo, dtype: bool

# %%
df.loc[ss3]
# Out:
#             nombres     fechas    saldo  al_corriente
# 1     María Sánchez 1989-01-13   5345.0          True
# 3  Rodrigo Martínez 1993-07-08  11323.2          True

# %%
#los que no tengan saldo positivo
df.loc[~ss3]
# Out:
#         nombres     fechas   saldo  al_corriente
# 0    Juan Pérez 1995-12-21  2500.0          True
# 2  Jorge Vargas 1992-09-14     NaN         False

# %%
#los que estan al corriente
df.loc[df['al_corriente']]
# Out:
#             nombres     fechas    saldo  al_corriente
# 0        Juan Pérez 1995-12-21   2500.0          True
# 1     María Sánchez 1989-01-13   5345.0          True
# 3  Rodrigo Martínez 1993-07-08  11323.2          True

# %%
df.loc[df['al_corriente'],'nombres':'saldo']
# Out:
#             nombres     fechas    saldo
# 0        Juan Pérez 1995-12-21   2500.0
# 1     María Sánchez 1989-01-13   5345.0
# 3  Rodrigo Martínez 1993-07-08  11323.2

# %%
df_null=df.isnull()
df_null
# Out:
#    nombres  fechas  saldo  al_corriente
# 0    False   False  False         False
# 1    False   False  False         False
# 2    False   False   True         False
# 3    False   False  False         False

# %%
#isnull numero de datos faltantes por columna
print(type(df.isnull().sum()))
df.isnull().sum()
# Out:
# <class 'pandas.core.series.Series'>
# nombres         0
# fechas          0
# saldo           1
# al_corriente    0
# dtype: int64

# %%
#isnull numero de datos faltantes por total
df.isnull().sum().sum()
# Out:
# 1

# %%
df.isnull().values
# Out:
# array([[False, False, False, False],
#        [False, False, False, False],
#        [False, False,  True, False],
#        [False, False, False, False]])

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().any()
# Out:
# nombres         False
# fechas          False
# saldo            True
# al_corriente    False
# dtype: bool

# %%
df[df.isnull().any(1)]
# Out:
# <ipython-input-59-d169372ee7ff>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   df[df.isnull().any(1)]
#         nombres     fechas  saldo  al_corriente
# 2  Jorge Vargas 1992-09-14    NaN         False
